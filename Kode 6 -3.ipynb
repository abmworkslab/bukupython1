# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tinggiberat500.csv")

# %%
df.shape

# %%
df.dtypes

# %%
df.head()

# %%
df.tail()

# %%
df.isna().sum()

# %%
df_baru= df[["Height"]]
df_baru

# %%
jumlah_row = 1
jumlah_column = 2 
lebar = 12
tinggi = 3 
fig, axs = plt.subplots(jumlah_row,jumlah_column,figsize=(lebar,tinggi))
sns.histplot(data=df_baru, x="Height",kde=True, ax=axs[0])
sns.boxplot(data=df_baru, x="Height", ax=axs[1])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_baru)
df_scaled = scaler.transform(df_baru)

# %%
from sklearn.cluster import KMeans
Y_prediksi = km.fit_predict(df_scaled)

# %%
df_baru["Kategori"] = y_prediksi

# %%
df_baru.head()
